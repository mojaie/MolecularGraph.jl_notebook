# %% [markdown]
# # Mass and isotopes
#
# MolecularGraph.jl version: 0.10.0
#
# This tutorial includes following fundamental operations related to molecular mass and isotopes.
#
# - Standard molecular weight
# - Relative molecular mass (Calculated exact mass)
# - Monoisotopic mass
# - Isotopic composition
# - Simulate mass spectrum

# %% [markdown]
# ## Loading packages
#
# This tutorial uses `Plots.jl` to display simulated mass spectrum.

# %%
using Pkg
Pkg.activate("..")
using MolecularGraph
using Plots

# To display a pair of mol images
function displayimgpair(img1, img2)
    """<div>
        <div style="float:left">$(img1)</div>
        <div style="float:left">$(img2)</div>
    </div>"""
end

nothing
# Out:
#   Activating environment at `~/Repository/MolecularGraph.jl_notebook/Project.toml`
# Path `../../MolecularGraph.jl` exists and looks like the correct package. Using existing path.
#    Resolving package versions...
#   No Changes to `~/Repository/MolecularGraph.jl_notebook/Project.toml`
#   No Changes to `~/Repository/MolecularGraph.jl_notebook/Manifest.toml`

# %% [markdown]
# ## Molecular weight (Relative molecular mass)
#
# Molecular weight (Relative molecular mass) can be calculated by `standardweight` method.

# %%
standardweight(smilestomol("CCO"))
# Out:
# (46.069, 0.004529999999995926)

# %% [markdown]
# - `standardweight` returns the tuple of standard weight and its uncertainty, respectively. The result shown above means the molecular weight of C2H5O is 46.069±0.005.
# - If you dont need uncertainty, give Float64 type to the method. Then the value will be rounded at 2 digits after the decimal point.

# %%
standardweight(Float64, smilestomol("CCO"))
# Out:
# 46.07

# %% [markdown]
# ## Calculated exact mass and monoisotopic mass
#
# Both `exactmass` and `monoisotopicmass` returns exact mass of the given molecule. The difference is that `exactmass` considers atomic mass specified in `Atom.mass` fields of atoms whereas `monoisotopicmass` always returns exact mass of the molecule consists of the most abundant isotopes in terrestrial sources.

# %%
etohd6 = smilestomol("[2H]C([2H])([2H])C([2H])([2H])O[2H]")

println("Molecular weight: ", standardweight(Float64, etohd6))
println("Monoisotopic: ", monoisotopicmass(Float64, etohd6))
println("Exact: ", exactmass(Float64, etohd6))
# Out:
# Molecular weight: 52.11
# Monoisotopic: 46.041865
# Exact: 52.079525

# %% [markdown]
# ## Isotopic composition
#
# `isotopiccomposition(atomsymbol, num)` returns total masses of the given number of atoms and their isotopic compositions.
#
# Isotopes that have lower abundance than the `threshold` parameter will be filtered out (default 0.001 = 0.1%)

# %%
isotopiccomposition(:C, 100; threshold=0.01)
# Out:
# 5-element Vector{Tuple{Float64, Float64}}:
#  (1204.01341934028, 0.01829972319797687)
#  (1203.01006450521, 0.06977096630391633)
#  (1202.00670967014, 0.19747098047720194)
#  (1201.00335483507, 0.36875136628763155)
#  (1200.0, 0.3410365354703909)

# %%
isotopiccomposition(:C, 1000; threshold=0.01)
# Out:
# 15-element Vector{Tuple{Float64, Float64}}:
#  (12018.06038703126, 0.011690519214538612)
#  (12017.05703219619, 0.019792334300846457)
#  (12016.05367736112, 0.0316151371989973)
#  (12015.05032252605, 0.04748134937359465)
#  (12014.04696769098, 0.06678541451097929)
#  (12013.04361285591, 0.08758641222522136)
#  (12012.04025802084, 0.1065534144511583)
#  (12011.03690318577, 0.11953540283428146)
#  (12010.0335483507, 0.12279996975578453)
#  (12009.03019351563, 0.11456944727429401)
#  (12008.02683868056, 0.09610452890364467)
#  (12007.02348384549, 0.0715861101895721)
#  (12006.02012901042, 0.04661058275253684)
#  (12005.01677417535, 0.02598703123363034)
#  (12004.01341934028, 0.012061765298138035)

# %% [markdown]
# `isotopiccomposition(mol)` returns isotopic composition of the molecule.

# %%
isotopiccomposition(smilestomol("CCO"))
# Out:
# 3-element Vector{Tuple{Float64, Float64}}:
#  (46.041864812949996, 0.9756627354527866)
#  (47.045219648019994, 0.02109374866472255)
#  (48.04610980624, 0.0020049807108054704)

# %% [markdown]
# ## Simulate mass spectrum
#
# According to the isotopic composition, simulated mass spectrum can be plotted by using `simulatemassspec` method and available plot libraries.
# Follwing example uses Plots.jl to draw the simulated spectrum.

# %%
mol = smilestomol("c1cc(ccc1[C@H]([C@@H](CO)NC(=O)C(Cl)Cl)O)[N+](=O)[O-]")
structure = drawsvg(mol, 200, 200)
data = simulatemassspec(mol)
p = plot(data[:, 1], data[:, 2], size=(320, 240), leg=false, xlabel = "Mass", ylabel = "Intensity")
buf = IOBuffer()
show(buf, MIME("image/svg+xml"), p)
spectrum = String(take!(buf))
close(buf)
display("text/html", displayimgpair(structure, spectrum))
# Out:
# <div>
#     <div style="float:left"><svg xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
#  version="1.2" baseProfile="tiny"
#  text-rendering="geometricPrecision"
#  preserveAspectRatio="xMidYMid meet"
#  font-weight="normal"
#  font-family="Helvetica"
#  width="200" height="200"
#  viewBox="0 0 319.83 179.84">
# <rect x="0" y="0" width="319.83" height="179.84"
#  fill="rgb(255, 255, 255)" opacity="0.0"/>
# <line x1="133.92" y1="74.94" x2="133.95" y2="104.94" stroke="rgb(0, 0, 0)" /><line x1="129.43" y1="77.94" x2="129.45" y2="101.94" stroke="rgb(0, 0, 0)" /><line x1="237.87" y1="104.86" x2="263.86" y2="119.84" stroke="rgb(0, 0, 0)" /><line x1="81.96" y1="74.98" x2="72.86" y2="69.74" stroke="rgb(0, 0, 0)" />
# <line x1="72.86" y1="69.74" x2="63.77" y2="64.49" stroke="rgb(0, 0, 255)" />
# <line x1="200.89" y1="78.91" x2="195.63" y2="69.82" stroke="rgb(0, 0, 0)" />
# <line x1="195.63" y1="69.82" x2="190.37" y2="60.73" stroke="rgb(255, 0, 0)" />
# <polygon points="0,0 1,1 1,-1" fill="rgb(0, 0, 0)" transform="matrix(10.52 18.18 -2.73 1.58 159.94 119.92)"/>
# <line x1="263.86" y1="119.84" x2="272.95" y2="114.58" stroke="rgb(0, 0, 0)" />
# <line x1="272.95" y1="114.58" x2="282.04" y2="109.32" stroke="rgb(64, 192, 64)" />
# <line x1="107.98" y1="119.96" x2="81.99" y2="104.98" stroke="rgb(0, 0, 0)" /><line x1="107.63" y1="114.56" x2="86.83" y2="102.58" stroke="rgb(0, 0, 0)" /><g stroke-width="0.3" transform="matrix(-1.50 2.60 -0.39 -0.22 159.94 119.92)">
#  <line x1="0" y1="1" x2="0" y2="-1" stroke="rgb(0, 0, 0)" />
#  <line x1="1" y1="2" x2="1" y2="-2" stroke="rgb(0, 0, 0)" />
#  <line x1="2" y1="3" x2="2" y2="-3" stroke="rgb(0, 0, 0)" />
#  <line x1="3" y1="4" x2="3" y2="-4" stroke="rgb(0, 0, 0)" />
#  <line x1="4" y1="5" x2="4" y2="-5" stroke="rgb(255, 0, 0)" />
#  <line x1="5" y1="6" x2="5" y2="-6" stroke="rgb(255, 0, 0)" />
#  <line x1="6" y1="7" x2="6" y2="-7" stroke="rgb(255, 0, 0)" />
#  <line x1="7" y1="8" x2="7" y2="-8" stroke="rgb(255, 0, 0)" />
# </g>
# <line x1="48.18" y1="64.51" x2="42.98" y2="67.51" stroke="rgb(0, 0, 255)" />
# <line x1="42.98" y1="67.51" x2="37.79" y2="70.51" stroke="rgb(255, 0, 0)" />
# <line x1="133.95" y1="104.94" x2="107.98" y2="119.96" stroke="rgb(0, 0, 0)" /><polygon points="0,0 1,1 1,-1" fill="rgb(0, 0, 0)" transform="matrix(14.98 -25.99 3.90 2.25 185.91 104.90)"/>
# <line x1="159.94" y1="119.92" x2="185.91" y2="104.90" stroke="rgb(0, 0, 0)" /><line x1="219.69" y1="115.37" x2="228.78" y2="110.12" stroke="rgb(0, 0, 255)" />
# <line x1="228.78" y1="110.12" x2="237.87" y2="104.86" stroke="rgb(0, 0, 0)" />
# <line x1="81.96" y1="74.98" x2="107.93" y2="59.96" stroke="rgb(0, 0, 0)" /><line x1="86.81" y1="77.37" x2="107.59" y2="65.36" stroke="rgb(0, 0, 0)" /><line x1="133.95" y1="104.94" x2="159.94" y2="119.92" stroke="rgb(0, 0, 0)" /><line x1="107.93" y1="59.96" x2="133.92" y2="74.94" stroke="rgb(0, 0, 0)" /><line x1="185.91" y1="104.90" x2="195.01" y2="110.14" stroke="rgb(0, 0, 0)" />
# <line x1="195.01" y1="110.14" x2="204.10" y2="115.38" stroke="rgb(0, 0, 255)" />
# <line x1="240.12" y1="104.86" x2="240.11" y2="94.36" stroke="rgb(0, 0, 0)" />
# <line x1="240.11" y1="94.36" x2="240.10" y2="83.86" stroke="rgb(255, 0, 0)" />
# <line x1="235.62" y1="104.86" x2="235.61" y2="94.36" stroke="rgb(0, 0, 0)" />
# <line x1="235.61" y1="94.36" x2="235.60" y2="83.86" stroke="rgb(255, 0, 0)" />
# <line x1="81.99" y1="104.98" x2="81.96" y2="74.98" stroke="rgb(0, 0, 0)" /><g stroke="rgb(0, 0, 0)" stroke-width="0.3" transform="matrix(-1.50 -2.60 0.39 -0.23 185.91 104.90)">
#  <line x1="0" y1="1" x2="0" y2="-1" />
#  <line x1="1" y1="2" x2="1" y2="-2" />
#  <line x1="2" y1="3" x2="2" y2="-3" />
#  <line x1="3" y1="4" x2="3" y2="-4" />
#  <line x1="4" y1="5" x2="4" y2="-5" />
#  <line x1="5" y1="6" x2="5" y2="-6" />
#  <line x1="6" y1="7" x2="6" y2="-7" />
#  <line x1="7" y1="8" x2="7" y2="-8" />
# </g>
# <line x1="263.86" y1="119.84" x2="263.87" y2="130.34" stroke="rgb(0, 0, 0)" />
# <line x1="263.87" y1="130.34" x2="263.88" y2="140.84" stroke="rgb(64, 192, 64)" />
# <line x1="58.21" y1="51.00" x2="58.21" y2="45.00" stroke="rgb(0, 0, 255)" />
# <line x1="58.21" y1="45.00" x2="58.20" y2="39.00" stroke="rgb(255, 0, 0)" />
# <line x1="53.71" y1="51.00" x2="53.71" y2="45.00" stroke="rgb(0, 0, 255)" />
# <line x1="53.71" y1="45.00" x2="53.70" y2="39.00" stroke="rgb(255, 0, 0)" />
# <text x="55.97" y="67.00" font-size="14.0"
#  fill="rgb(0, 0, 255)" text-anchor="middle" >N<tspan baseline-shift="50%" font-size="10">+</tspan></text>
# <text x="192.87" y="59.94" font-size="14.0"
#  fill="rgb(255, 0, 0)" text-anchor="end" >HO</text>
# <text x="174.96" y="152.89" font-size="14.0"
#  fill="rgb(0, 0, 0)" text-anchor="middle" >H</text>
# <text x="289.83" y="111.82" font-size="14.0"
#  fill="rgb(64, 192, 64)" text-anchor="middle" >Cl</text>
# <text x="151.96" y="152.91" font-size="14.0"
#  fill="rgb(255, 0, 0)" text-anchor="end" >HO</text>
# <text x="30.00" y="82.02" font-size="14.0"
#  fill="rgb(255, 0, 0)" text-anchor="middle" >O<tspan baseline-shift="50%" font-size="10">–</tspan></text>
# <text x="211.90" y="126.88" font-size="14.0"
#  fill="rgb(0, 0, 255)" text-anchor="middle" >NH</text>
# <text x="237.85" y="81.86" font-size="14.0"
#  fill="rgb(255, 0, 0)" text-anchor="middle" >O</text>
# <text x="170.89" y="85.93" font-size="14.0"
#  fill="rgb(0, 0, 0)" text-anchor="middle" >H</text>
# <text x="263.89" y="156.84" font-size="14.0"
#  fill="rgb(64, 192, 64)" text-anchor="middle" >Cl</text>
# <text x="55.94" y="37.00" font-size="14.0"
#  fill="rgb(255, 0, 0)" text-anchor="middle" >O</text>
# </svg>
# </div>
#     <div style="float:left"><?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="320" height="240" viewBox="0 0 1280 960">
# <defs>
#   <clipPath id="clip190">
#     <rect x="0" y="0" width="1280" height="960"/>
#   </clipPath>
# </defs>
# <path clip-path="url(#clip190)" d="
# M0 960 L1280 960 L1280 0 L0 0  Z
#   " fill="#ffffff" fill-rule="evenodd" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip191">
#     <rect x="256" y="0" width="897" height="897"/>
#   </clipPath>
# </defs>
# <path clip-path="url(#clip190)" d="
# M227.129 779.32 L1232.76 779.32 L1232.76 47.2441 L227.129 47.2441  Z
#   " fill="#ffffff" fill-rule="evenodd" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip192">
#     <rect x="227" y="47" width="1007" height="733"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip192)" style="stroke:#000000; stroke-linecap:butt; stroke-linejoin:round; stroke-width:2; stroke-opacity:0.1; fill:none" points="
#   391.12,779.32 391.12,47.2441
#   "/>
# <polyline clip-path="url(#clip192)" style="stroke:#000000; stroke-linecap:butt; stroke-linejoin:round; stroke-width:2; stroke-opacity:0.1; fill:none" points="
#   662.178,779.32 662.178,47.2441
#   "/>
# <polyline clip-path="url(#clip192)" style="stroke:#000000; stroke-linecap:butt; stroke-linejoin:round; stroke-width:2; stroke-opacity:0.1; fill:none" points="
#   933.236,779.32 933.236,47.2441
#   "/>
# <polyline clip-path="url(#clip192)" style="stroke:#000000; stroke-linecap:butt; stroke-linejoin:round; stroke-width:2; stroke-opacity:0.1; fill:none" points="
#   1204.29,779.32 1204.29,47.2441
#   "/>
# <polyline clip-path="url(#clip190)" style="stroke:#000000; stroke-linecap:butt; stroke-linejoin:round; stroke-width:4; stroke-opacity:1; fill:none" points="
#   227.129,779.32 1232.76,779.32
#   "/>
# <polyline clip-path="url(#clip190)" style="stroke:#000000; stroke-linecap:butt; stroke-linejoin:round; stroke-width:4; stroke-opacity:1; fill:none" points="
#   391.12,779.32 391.12,760.422
#   "/>
# <polyline clip-path="url(#clip190)" style="stroke:#000000; stroke-linecap:butt; stroke-linejoin:round; stroke-width:4; stroke-opacity:1; fill:none" points="
#   662.178,779.32 662.178,760.422
#   "/>
# <polyline clip-path="url(#clip190)" style="stroke:#000000; stroke-linecap:butt; stroke-linejoin:round; stroke-width:4; stroke-opacity:1; fill:none" points="
#   933.236,779.32 933.236,760.422
#   "/>
# <polyline clip-path="url(#clip190)" style="stroke:#000000; stroke-linecap:butt; stroke-linejoin:round; stroke-width:4; stroke-
